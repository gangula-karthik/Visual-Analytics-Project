# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://esingaporeproperty.sg/property-type/condo-private-new/"

# Fetch the HTML content of the website
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# Find the main `ul` element with class `large-block-grid-2 medium-block-grid-2`
ul_element = soup.find("ul", class_="large-block-grid-2 medium-block-grid-2")

# %%
print(ul_element.prettify())
type(ul_element)
# Out:
# <ul class="large-block-grid-2 medium-block-grid-2">
#  <li>
#   <div class="card">
#    <div class="img-wrap">
#     <a href="https://esingaporeproperty.sg/property/terra-hill-condo/">
#      <img alt="For Illustration Only . Flynn Park Residences" class="attachment-card size-card wp-post-image" decoding="async" height="375" src="https://esingaporeproperty.sg/wp-content/uploads/2018/04/For-Illustration-Only-Flynn-Park-Residences-675x375.jpg" width="675"/>
#     </a>
#     <div class="badge">
#      <div class="status">
#       <ul class="meta-list">
#        <li>
#         <a href="https://esingaporeproperty.sg/property-status/tenure-freehold/" rel="tag">
#          Freehold
#         </a>
#        </li>
#        <li>
#         <a href="https://esingaporeproperty.sg/property-status/developer-upcoming-launch/" rel="tag">
#          Upcoming Launch
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <div class="content-wrap">
# ...

# %%
for div_element in ul_element.find_all("div", class_="img-wrap"):
    div_element.decompose()

li_elements = str(ul_element).split("<div class=\"card\">")[1:]
li_elements[]
# Out:
# ['\n\n<div class="content-wrap">\n<div class="title"><a href="https://esingaporeproperty.sg/property/terra-hill-condo/">Terra Hill</a></div>\n<ul class="meta-list">\n<li><a href="https://esingaporeproperty.sg/property-location/d05/" rel="tag">D05 . Buona Vista . West Coast . Clementi</a></li><li><a href="https://esingaporeproperty.sg/property-location/singapore/" rel="tag">Singapore</a></li></ul>\n<ul class="meta-box-list">\n</ul>\n</div>\n</div>\n</li>\n<li>',
# ...

# %%
property_names = []
top_date = []

for i in li_elements:
    soup = BeautifulSoup(i, "html.parser")
    prop_element = soup.find("div", class_="title")
    top_element = soup.find_all("li") 
    third_li = top_element[2]
    print(str(third_li.text))
    text = prop_element.a.text
    property_names.append(text)

property_names
# Out:
#  TOP 2027
#  TOP 2027
#  TOP 2026
#  TOP 2026
#  TOP 2024
#  TOP 2022
#  TOP 2025
#  TOP 2026
#  TOP 2022
#  TOP 2026
#  TOP 2021
# ['Terra Hill',
#  'The Botany at Dairy Farm',
#  'Sceneca Residence',
#  'Lentor Modern',
#  'AMO Residence',
#  'LIV @ MB',
#  'The Gazania',
#  'Canninghill Piers',
#  'Piccadilly Grand',
#  '15 Holland Hill',
#  'Mori @ Guillemard',
#  'MeyerHouse']

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup


def getter_top_dates(): 
    property_names = []
    top_date = []

    for i in range(1, 10): 
        url = f"https://esingaporeproperty.sg/property-type/condo-private-new/page/{i}/"
        response = requests.get(url)
        soup = BeautifulSoup(response.text, "html.parser")

        ul_element = soup.find("ul", class_="large-block-grid-2 medium-block-grid-2")
        
        for div_element in ul_element.find_all("div", class_="img-wrap"):
            div_element.decompose()

        li_elements = str(ul_element).split("<div class=\"card\">")[1:]
        for i in li_elements:
            soup = BeautifulSoup(i, "html.parser")
            prop_element = soup.find("div", class_="title")
            print(prop_element)

            top_element = soup.find_all("li") 
            third_li = top_element[2]
            print(str(third_li.text))

            if top_element is None: 
                top_date.append(None)
            else: 
                top_date.append(str(third_li.text))
        
            text = prop_element.a.text
            property_names.append(text)

    return pd.DataFrame(data={'Property_names': property_names, 'TOP_year': top_date})


getter_top_dates()
# Out:
# <div class="title"><a href="https://esingaporeproperty.sg/property/terra-hill-condo/">Terra Hill</a></div>
#
# <div class="title"><a href="https://esingaporeproperty.sg/property/the-botany-at-dairy-farm/">The Botany at Dairy Farm</a></div>
#  TOP 2027
# <div class="title"><a href="https://esingaporeproperty.sg/property/sceneca-residence/">Sceneca Residence</a></div>
#  TOP 2027
# <div class="title"><a href="https://esingaporeproperty.sg/property/lentor-modern/">Lentor Modern</a></div>
#  TOP 2026
# <div class="title"><a href="https://esingaporeproperty.sg/property/amo-residences/">AMO Residence</a></div>
#  TOP 2026
# <div class="title"><a href="https://esingaporeproperty.sg/property/liv-mb-condo/">LIV @ MB</a></div>
#  TOP 2024
# <div class="title"><a href="https://esingaporeproperty.sg/property/the-gazania-condo/">The Gazania</a></div>
#  TOP 2022
# <div class="title"><a href="https://esingaporeproperty.sg/property/canninghill-piers-condo/">Canninghill Piers</a></div>
#  TOP 2025
# ...

# %%
missing_data = """
Newport Residences = 2028
Boulevard 88 = 2022
Piermont Grand = 2022
Midwood = 2022
Verdale = 2024
One Holland Village Residences = 2024
Parc Komo/Komo Shoppes = 2024
Kassia = 2027
Terra Hill = 2026
The Continuum = 2027
Tembusu Grand = 2028
Marina View Residences = 2026 
Urban Treasures = 2023
The Landmark = 2025
Dairy Farm Residences/Dairy Farm Mall = 2027
Ola = 2023
Forett at Bukit Timah = 2025
Parc Central Residences = 2025
Penrose = 2025
Pollen Collection = 2026
Provence Residence = 2024
Parc Greenwich = 2024
The Commodore = 2026
Skywaters Residences = 2027
Copen Grand = 2027
"""


property_names = []
top_years = []

for line in missing_data.split('\n')[1:]:
    temp = line.split(" = ")
    name = temp[0]
    year = temp[1]
    property_names.append(name)
    top_years.append(int(year))

print(property_names)
print(top_years)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [34], line 36
#      34 temp = line.split(" = ")
#      35 name = temp[0]
# ---> 36 year = temp[1]
#      37 property_names.append(name)
#      38 top_years.append(int(year))
#
# IndexError: list index out of range

# %%
top_years
# Out:
# [2028,
#  2022,
#  2022,
#  2022,
#  2024,
#  2024,
#  2024,
#  2027,
#  2026,
#  2027,
#  2028,
#  2026,
#  2023,
#  2025,
#  2027,
#  2023,
#  2025,
#  2025,
#  2025,
#  2026,
#  2024,
#  2024,
#  2026,
#  2027,
#  2027]

# %%
import pandas as pd

data = {'Property_names': property_names,
         'TOP_year': top_years}
df = pd.DataFrame(data)
df
# Out:
#                            Property_names  TOP_year
# 0                      Newport Residences      2028
# 1                            Boulevard 88      2022
# 2                          Piermont Grand      2022
# 3                                 Midwood      2022
# 4                                 Verdale      2024
# 5          One Holland Village Residences      2024
# 6                  Parc Komo/Komo Shoppes      2024
# 7                                  Kassia      2027
# 8                              Terra Hill      2026
# 9                           The Continuum      2027
# 10                          Tembusu Grand      2028
# 11                 Marina View Residences      2026
# 12                        Urban Treasures      2023
# 13                           The Landmark      2025
# 14  Dairy Farm Residences/Dairy Farm Mall      2027
# 15                                    Ola      2023
# 16                  Forett at Bukit Timah      2025
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d10a9bce-ccf4-48fc-b2f9-9f42f99a7043' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
